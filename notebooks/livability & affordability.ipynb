# %% [markdown]
# ## Livability & Affordability

# %% [markdown]
# ### Import Libraries

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# ### Inspect datasets

# %%
liveable_count = pd.read_csv('../data/curated/liveable_count.csv')
liveable_count.head()
# Out:
#                       sa2_name  independent_school_count  station_count  \
# 0            Caulfield - North                  1.000000          0.875
# 1                   Camberwell                  0.555556          1.000
# 2             Richmond - North                  0.333333          0.625
# 3                Hawthorn East                  0.666667          0.625
# 4  Richmond (South) - Cremorne                  0.555556          0.625
#
#    hospital_count  parkres_count  recreation_facilities_count  \
# 0        0.666667         0.0000                     0.052083
# 1        0.666667         0.0000                     0.000000
# 2        0.833333         0.0250                     0.783333
# 3        0.833333         0.0000                     0.070833
# 4        0.833333         0.0125                     0.000000
#
#    shopping_centres_count  extracted_price  crime_frequency  total_value_lost  \
# 0                     0.1         0.403594           1165.0       15116873.32
# 1                     0.1         0.453309            644.0       19190532.02
# 2                     0.1         0.410520           1573.0       30116731.05
# 3                     0.0         0.405218            587.0       12070259.75
# 4                     0.0         0.478403              0.0              0.00
#
#    total_items_lost  ERP_2021  crime_rate_per_1000  avg_cbd_distance_km  \
# 0           21260.0   22723.0             0.003671             0.177991
# 1           22268.0   21500.0             0.002145             0.211755
# 2           52839.0   14074.0             0.008004             0.067844
# 3           14360.0   15881.0             0.002647             0.176793
# 4               0.0   17977.0             0.000000             0.076838
#
#    liveability_index
# 0           0.329992
# 1           0.300698
# 2           0.291447
# 3           0.272899
# 4           0.270735

# %% [markdown]
# ### Merge datasets
